# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-f83ebab1-9da8-4447-808b-603a2274aef9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f83ebab1-9da8-4447-808b-603a2274aef9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from tensorflow.keras.models import load_model
model = load_model("plant_disease_model.keras")

# %%
class_names= ['Grape_Grape___Black_rot', 'Grape_Grape___Esca_(Black_Measles)', 'Grape_Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Grape_Grape___healthy', 'apple_Apple___Apple_scab', 'apple_Apple___Black_rot', 'apple_Apple___Cedar_apple_rust', 'apple_Apple___healthy', 'cashew_Cashew_healthy', 'cashew_Cashew_leaf_miner', 'cashew_Cashew_red_rust', 'corn_Corn_(maize)___Cercospora_leaf_spot_Gray_leaf_spot', 'corn_Corn_(maize)___Common_rust_', 'corn_Corn_(maize)___Northern_Leaf_Blight', 'corn_Corn_(maize)___healthy', 'cotton_bacterial_blight', 'cotton_curl_virus', 'cotton_fussarium_wilt', 'cotton_healthy', 'millets_Healthy', 'millets_blast', 'millets_rust', 'potato_Potato___Early_blight', 'potato_Potato___Late_blight', 'potato_Potato___healthy', 'rice_bacterial_leaf_blight', 'rice_brown_spot', 'rice_healthy', 'rice_hispa', 'rice_leaf_blast', 'rice_leaf_scald', 'rice_narrow_brown_spot', 'rice_neck_blast', 'rice_sheath_blight', 'rice_tungro', 'sugar_cane_Healthy', 'sugar_cane_Mosaic', 'sugar_cane_RedRot', 'sugar_cane_Rust', 'sugar_cane_Yellow', 'tomato_Tomato___Bacterial_spot', 'tomato_Tomato___Early_blight', 'tomato_Tomato___Late_blight', 'tomato_Tomato___Leaf_Mold', 'tomato_Tomato___Septoria_leaf_spot', 'tomato_Tomato___Spider_mites_Two-spotted_spider_mite', 'tomato_Tomato___Target_Spot', 'tomato_Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'tomato_Tomato___Tomato_mosaic_virus', 'tomato_Tomato___healthy', 'wheat_brown_rust', 'wheat_healthy', 'wheat_loose_smut', 'wheat_septoria', 'wheat_yellow_rust']

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d4bd265e-d144-4288-9378-402dcd931304" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d4bd265e-d144-4288-9378-402dcd931304">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from keras.preprocessing import image
import numpy as np
img = image.load_img('42e774fe-ff8e-4044-8dd5-5deedc64c991___FAM_B.Rot 3148.JPG', target_size=(160, 160))
img_array=image.img_to_array(img)
img_array=img_array/255.0
img_array = np.expand_dims(img_array, axis=0)
predictions = model.predict(img_array)
print(predictions)
predicted_class_index = np.argmax(predictions, axis=1)[0]
print("Predicted Class Index:-", predicted_class_index)
print(class_names[predicted_class_index])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# [[9.9805331e-01 8.7229675e-04 1.8338249e-04 7.9187780e-04 2.1855678e-05
#   4.7219612e-05 4.5243669e-07 2.8993318e-06 1.0698726e-08 8.8814275e-08
#   8.9491863e-09 1.7163266e-08 2.8357579e-08 6.1202329e-08 2.2744824e-09
#   9.8205564e-06 9.7381815e-07 1.5001432e-05 6.0361288e-07]]
# Predicted Class Index:- 0
# Grape_Grape___Black_rot

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7f593d87-ceb7-4660-b379-968e8b5b5597" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f593d87-ceb7-4660-b379-968e8b5b5597">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from keras.preprocessing import image
import numpy as np
img = image.load_img('RS_Rust 1970.JPG', target_size=(160, 160))
img_array=image.img_to_array(img)
img_array=img_array/255.0
img_array = np.expand_dims(img_array, axis=0)
predictions = model.predict(img_array)
print(predictions)
predicted_class_index = np.argmax(predictions, axis=1)[0]
print("Predicted Class Index:-", predicted_class_index)
print(class_names[predicted_class_index])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# [[1.6034962e-09 2.2776034e-08 1.8959659e-08 3.5941763e-10 5.0524195e-06
#   3.8331940e-08 4.3661731e-07 9.1626333e-08 2.2367566e-08 6.4668990e-07
#   3.6675970e-06 9.5233254e-06 9.9996197e-01 1.5627333e-05 4.2008175e-09
#   2.7271021e-06 1.2250263e-07 1.6942217e-08 2.9547666e-08]]
# Predicted Class Index:- 12
# corn_Corn_(maize)___Common_rust_

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7f7572e3-77e7-4def-9cf7-5acc988f94e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7f7572e3-77e7-4def-9cf7-5acc988f94e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from keras.preprocessing import image
import numpy as np
img = image.load_img('d51d9b23-0d18-472f-932a-c6b86796b596___RS_GLSp 4500 copy 2_90deg.jpg', target_size=(160, 160))
img_array=image.img_to_array(img)
img_array=img_array/255.0
img_array = np.expand_dims(img_array, axis=0)
predictions = model.predict(img_array)
print(predictions)
predicted_class_index = np.argmax(predictions, axis=1)[0]
print("Predicted Class Index:-", predicted_class_index)
print(class_names[predicted_class_index])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# [[1.14908874e-10 1.88739047e-09 9.39374942e-08 2.59826355e-10
#   2.44931698e-06 5.99237326e-09 4.11805695e-06 2.07853947e-08
#   1.32173883e-09 3.95051464e-10 1.50825645e-08 9.99980092e-01
#   4.05079525e-08 1.26231080e-05 2.08724103e-07 3.26111973e-08
#   2.30273542e-08 3.84267565e-07 1.85953404e-08]]
# Predicted Class Index:- 11
# corn_Corn_(maize)___Cercospora_leaf_spot_Gray_leaf_spot

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-a0c2ac16-f2af-42a8-96b2-549bb3c5df67" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0c2ac16-f2af-42a8-96b2-549bb3c5df67">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from keras.preprocessing import image
import numpy as np
img = image.load_img('1 (420).jpg', target_size=(160, 160))
img_array=image.img_to_array(img)
img_array=img_array/255.0
img_array = np.expand_dims(img_array, axis=0)
predictions = model.predict(img_array)
print(predictions)
predicted_class_index = np.argmax(predictions, axis=1)[0]
print("Predicted Class Index:-", predicted_class_index)
print(class_names[predicted_class_index])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# [[1.7831362e-05 5.7904509e-07 9.0355388e-06 6.4317483e-06 6.5086911e-05
#   3.9173187e-06 1.5690232e-04 2.5301299e-06 1.0178019e-02 8.9201909e-01
#   8.6177483e-02 3.1135473e-04 8.1379592e-05 2.1683370e-06 1.2861732e-04
#   2.1910634e-04 4.8969449e-03 5.6492132e-03 7.4374620e-05]]
# Predicted Class Index:- 9
# cashew_Cashew_leaf_miner

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-73619830-65ae-459b-b72b-8a95711a351e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-73619830-65ae-459b-b72b-8a95711a351e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from keras.preprocessing import image
import numpy as np
img = image.load_img('h260.jpg', target_size=(160, 160))
img_array=image.img_to_array(img)
img_array=img_array/255.0
img_array = np.expand_dims(img_array, axis=0)
predictions = model.predict(img_array)
print(predictions)
predicted_class_index = np.argmax(predictions, axis=1)[0]
print("Predicted Class Index:-", predicted_class_index)
print(class_names[predicted_class_index])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# [[3.3995591e-05 6.4377144e-07 1.1343502e-07 1.1483041e-05 4.1558487e-06
#   1.4703780e-07 2.4443514e-06 4.3775264e-05 4.4754534e-06 4.0120572e-06
#   6.3289013e-07 4.4836193e-07 5.2858616e-07 3.5449528e-08 4.7929257e-07
#   7.0561696e-04 1.8071700e-05 1.2097879e-04 9.9904794e-01]]
# Predicted Class Index:- 18
# cotton_healthy

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-7fa22aa2-87c6-4439-ad86-e972f54c5d96" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7fa22aa2-87c6-4439-ad86-e972f54c5d96">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from keras.preprocessing import image
import numpy as np
img = image.load_img('d46c67aa-e05c-48f7-9287-fbc727396c9e___FREC_C.Rust 4036_90deg.JPG', target_size=(160, 160))
img_array=image.img_to_array(img)
img_array=img_array/255.0
img_array = np.expand_dims(img_array, axis=0)
predictions = model.predict(img_array)
print(predictions)
predicted_class_index = np.argmax(predictions, axis=1)[0]
print("Predicted Class Index:-", predicted_class_index)
print(class_names[predicted_class_index])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 721ms/step
# [[3.8143687e-06 3.5074258e-08 4.4379114e-05 3.5707262e-07 2.1656139e-02
#   5.5199215e-04 9.7767544e-01 2.1454178e-05 5.1897331e-08 3.4490627e-06
#   1.6696529e-06 1.6818378e-05 2.7078018e-08 1.4190141e-05 2.0885832e-08
#   1.4786747e-06 2.4634825e-09 8.7053941e-06 3.2550114e-09]]
# Predicted Class Index:- 6
# apple_Apple___Cedar_apple_rust
